# %% [markdown]
# <a href="https://colab.research.google.com/github/ajitkumarkp/CV/blob/master/anaconda_sample.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from PIL import Image
import cv2 as cv
import matplotlib.pyplot as plt

# %%
img = cv.imread("00-puppy.jpg")
img_bgr = cv.cvtColor(img, cv.COLOR_RGB2BGR) # for PLT

# %% [markdown]
# Exp1

# %%
# # Using PIL
# ## ndarray can be converted to a PIL.Image obj 
pil_img=Image.fromarray(img_bgr)
pil_img.show()

# %%
# Using Plt 
# plt.title("Puppy");plt.imshow(img_bgr);plt.show()

# %%
# # Using CV 
# cv.imshow("Puppy", img)
# cv.waitKey(0)

# %%
# !cat /etc/os-release
# !cat /proc/cpuinfo
# Out:
# NAME="Ubuntu"
# VERSION="18.04.3 LTS (Bionic Beaver)"
# ID=ubuntu
# ID_LIKE=debian
# PRETTY_NAME="Ubuntu 18.04.3 LTS"
# VERSION_ID="18.04"
# HOME_URL="https://www.ubuntu.com/"
# SUPPORT_URL="https://help.ubuntu.com/"
# BUG_REPORT_URL="https://bugs.launchpad.net/ubuntu/"
# PRIVACY_POLICY_URL="https://www.ubuntu.com/legal/terms-and-policies/privacy-policy"
# VERSION_CODENAME=bionic
# UBUNTU_CODENAME=bionic
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2200.000
# cache size	: 56320 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# ...
